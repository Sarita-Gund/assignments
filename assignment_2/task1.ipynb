# %% [markdown]
# # Task-1.  Demonstrate minimum 15 basic docker command with explanation and screenshot.

# %% [markdown]
# 1. "docker --version"  This command is used to check the version.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. "docker pull <imqge>" this is used to pull the image from repository.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. "docker run" to run the image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.   "docker ps" to check the which image is running now

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. "docker build -t <name>" Thid command is used to build the image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. "docker run" to run the image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. "docker images" to list the images

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 8. " docker history image" used to show the image history

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 9. " docker inspect image" to show low lavel info

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 10. " docker container prune" to delete the stopper container

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 11. "docker create" to create a new container

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 12.c"docker start" to start the container

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 13. "docker commit" to save docker container

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 14. "docker tag" to tag the image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 15. "docker stop" to stop the contaier

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 16. "docker rm container" to delete container

# %% [markdown]
# ![image.png](attachment:image.png)
